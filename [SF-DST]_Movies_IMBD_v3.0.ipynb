# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
#print(os.listdir("../input"))

# %%
data = pd.read_csv('data.csv')
#data.head(5)
data
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# 5     tt1663202    9.110700  135000000   532950503
# 6     tt1340138    8.654359  155000000   440603537
# 7     tt3659388    7.667400  108000000   595380321
# 8     tt2293640    7.404165   74000000  1156730962
# 9     tt2096673    6.326804  175000000   853708609
# 10    tt2379713    6.200282  245000000   880674609
# 11    tt1617661    6.189369  176000003   183987723
# 12    tt0470752    6.118847   15000000    36869414
# 13    tt2120120    5.984995   88000000   243637091
# 14    tt2395427    5.944927  280000000  1405035767
# 15    tt3460252    5.898400   44000000   155760117
# 16    tt2446042    5.749758   48000000   325771424
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
data[data.budget >= 425000000]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year
# 491    12/2/2010          74           6.4          2010

# %%
data.groupby(['budget'])['original_title'].max().sort_index(ascending=False).head(1)
# Out:
# budget
# 425000000    The Warrior's Way
# Name: original_title, dtype: object

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data.groupby(['runtime'])['original_title'].max().sort_index(ascending=False).head(1)
# Out:
# runtime
# 214    Gods and Generals
# Name: original_title, dtype: object

# %%
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data.groupby(['runtime'])['original_title'].max().sort_index(ascending=True).head(1)
# Out:
# runtime
# 63    Winnie the Pooh
# Name: original_title, dtype: object

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %%
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data.groupby(['revenue'])['original_title'].max().sort_index(ascending=False).head(1)
# Out:
# revenue
# 2781505847    Avatar
# Name: original_title, dtype: object

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data['profit'] = data['revenue'] - data['budget']
data.groupby(['profit'])['original_title'].max().sort_index(ascending=True).head(1)
# Out:
# profit
# -413912431    The Warrior's Way
# Name: original_title, dtype: object

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
data[data.profit > 0].count()
# Out:
# imdb_id                 1478
# popularity              1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_count              1478
# vote_average            1478
# release_year            1478
# profit                  1478
# dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data2008 = data[data.release_year == 2008]
data2008.groupby(['profit'])['original_title'].max().sort_index(ascending=False).head(1)
# Out:
# profit
# 816921825    The Dark Knight
# Name: original_title, dtype: object

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data2012_14 = data.loc[(data.release_year >= 2012) & (data.release_year <= 2014)]
data2012_14.groupby(['profit'])['original_title'].max().sort_index(ascending=True).head(1)
# Out:
# profit
# -165710090    The Lone Ranger
# Name: original_title, dtype: object

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
data_genres = data.genres.str.split('|').sum()
Counter(data_genres).most_common(1)[0]
# Out:
# ('Drama', 782)

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
data_profit_above0 = data.loc[data.profit > 0]
data_profit_genres = data_profit_above0.genres.str.split('|').sum()
Counter(data_profit_genres).most_common(1)[0]
# Out:
# ('Drama', 560)

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data_director = data.director.str.split('|').sum()
Counter(data_director).most_common(1)[0]
# Out:
# ('Steven Soderbergh', 13)

# %%
answer_ls.append(3)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
data_profit_director = data_profit_above0.director.str.split('|').sum()
Counter(data_profit_director).most_common(1)[0]
# Out:
# ('Ridley Scott', 12)

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
data.query('director in ["Steven Spielberg"]').profit.sum()
# Out:
# 2449700791

# %%
data.query('director in ["Christopher Nolang"]').profit.sum()
# Out:
# 0

# %%
data.query('director in ["David Yates"]').profit.sum()
# Out:
# 3379295625

# %%
data.query('director in ["James Cameron"]').profit.sum()
# Out:
# 2548546718

# %%
data.query('director in ["Peter Jackson"]').profit.sum()
# Out:
# 5202593685

# %%
dict = {i: data[data['director'] == i].profit.sum() for i in data_director}
lst_dict = list(dict.items())
lst_dict.sort(key = lambda i: i[1], reverse=True)
lst_dict[0]
# Out:
# ('Peter Jackson', 5202593685)

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
data_cast = data.cast.str.split('|').sum()
Counter(data_cast).most_common(1)[0]
# Out:
# ('Samuel L. Jackson', 27)

# %%
dict1 = {i: data[data.cast.str.contains(i)].profit.sum() for i in data_cast}
lst_dict1 = list(dict1.items())
lst_dict1.sort(key = lambda i: i[1], reverse=True)

# %%
lst_dict1[0]
# Out:
# ('Emma Watson', 6666245597)

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
data2012 = data[data.release_year == 2012]
dict2 = {i: data2012[data2012.cast.str.contains(i)].profit.sum() for i in data_cast}
lst_dict2 = list(dict2.items())
lst_dict2.sort(key = lambda i: i[1], reverse=False)

# %%
lst_dict2[0]
# Out:
# ('Kirsten Dunst', -68109207)

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
movies_above_mean = data[data.budget > data.budget.mean()]
data_cast
data_profit_cast = movies_above_mean.cast.str.split('|').sum()
Counter(data_profit_cast).most_common(1)[0]
# Out:
# ('Matt Damon', 18)

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
data_nicolas_cage = data[data.cast.str.contains('Nicolas Cage')]
data_genres_nc = data_nicolas_cage.genres.str.split('|').sum()
Counter(data_genres_nc).most_common(1)[0]
# Out:
# ('Action', 17)

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
data_production_companies = data.production_companies.str.split('|').sum()
Counter(data_production_companies).most_common(1)[0]
# Out:
# ('Universal Pictures', 173)

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
data2015 = data[data.release_year == 2015]
data_production_companies_2015 = data2015.production_companies.str.split('|').sum()
Counter(data_production_companies_2015).most_common(1)[0]
# Out:
# ('Warner Bros.', 12)

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
data_comedy = data[data.genres.str.contains('Comedy')]
dict3 = {i: data_comedy[data_comedy.production_companies.str.contains(i)].profit.sum() for i in data_production_companies}
lst_dict3 = list(dict3.items())
lst_dict3.sort(key = lambda i: i[1], reverse=True)
# Out:
# /Users/viktorialavrinenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
lst_dict3
# Out:
# [('Universal', 9130349034),
#  ('Universal Pictures', 8952422726),
#  ('Twentieth Century Fox', 8239362666),
#  ('Disney', 8006316328),
#  ('Walt Disney', 7975933215),
#  ('Walt Disney Pictures', 7669710326),
#  ('Columbia Pictures', 7161805266),
#  ('DreamWorks', 6414759357),
#  ('Twentieth Century Fox Film Corporation', 5686960294),
#  ('DreamWorks Animation', 4789049764),
#  ('Warner Bros.', 4370928916),
#  ('Pixar Animation Studios', 4232507237),
#  ('New Line Cinema', 3259242692),
#  ('DreamWorks SKG', 3143226857),
#  ('Paramount Pictures', 3055625722),
#  ('Relativity Media', 3036733344),
#  ('Twentieth Century Fox Animation', 3030806037),
#  ('Blue Sky Studios', 3024335014),
#  ('Sony', 2749581444),
#  ('Sony Pictures', 2579196823),
#  ('Village Roadshow Pictures', 2450804648),
#  ('Dune Entertainment', 2207722237),
#  ('Happy Madison Productions', 2196445292),
#  ('Illumination Entertainment', 1977492847),
#  ('Columbia Pictures Corporation', 1817280373),
# ...

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
data_production_companies = data.production_companies.str.split('|').sum()
dict4 = {i: data2012[data2012.production_companies.str.contains(i)].profit.sum() for i in data_production_companies}
lst_dict4 = list(dict4.items())
lst_dict4.sort(key = lambda i: i[1], reverse=True)
# Out:
# /Users/viktorialavrinenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
lst_dict4
# Out:
# [('Columbia Pictures', 2501406608),
#  ('Universal Pictures', 1981011579),
#  ('Universal', 1981011579),
#  ('Twentieth Century Fox', 1508921607),
#  ('Marvel Studios', 1299557910),
#  ('Warner Bros.', 1258020056),
#  ('Relativity Media', 1032593938),
#  ('New Line Cinema', 1028114941),
#  ('Legendary Pictures', 982041287),
#  ('Summit Entertainment', 961582873),
#  ('Dune Entertainment', 892186707),
#  ('Syncopy', 831041287),
#  ('DC Entertainment', 831041287),
#  ('Blue Sky Studios', 782244782),
#  ('Twentieth Century Fox Animation', 782244782),
#  ('WingNut Films', 767003568),
#  ('DreamWorks Animation', 763862944),
#  ('DreamWorks', 742341999),
#  ('Disney', 726836264),
#  ('Walt Disney', 726836264),
#  ('Twentieth Century Fox Film Corporation', 726676825),
#  ('Lionsgate', 709309876),
#  ('Temple Hill Entertainment', 709000000),
#  ('Sunswept Entertainment', 709000000),
#  ('Color Force', 616210692),
#  ('Fox 2000 Pictures', 544128741),
#  ('Marvel Entertainment', 537215857),
# ...

# %%
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
data_Paramount_Pictures = data[data.production_companies.str.contains('Paramount Pictures')]
data_Paramount_Pictures.groupby(['profit'])['original_title'].max().sort_index(ascending=True).head(1)
# Out:
# profit
# -64831034    K-19: The Widowmaker
# Name: original_title, dtype: object

# %%
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data[data['release_year'] == 2014].profit.sum()
# Out:
# 16397812953

# %%
data[data['release_year'] == 2008].profit.sum()
# Out:
# 11663881990

# %%
data[data['release_year'] == 2012].profit.sum()
# Out:
# 16077001687

# %%
data[data['release_year'] == 2002].profit.sum()
# Out:
# 9002361487

# %%
data[data['release_year'] == 2015].profit.sum()
# Out:
# 18668572378

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
data_Warner_Bros = data[data.production_companies.str.contains('Warner Bros')]

# %%
data_Warner_Bros[data_Warner_Bros['release_year'] == 2014].profit.sum()
# Out:
# 2295464519

# %%
data_Warner_Bros[data_Warner_Bros['release_year'] == 2008].profit.sum()
# Out:
# 2134595031

# %%
data_Warner_Bros[data_Warner_Bros['release_year'] == 2012].profit.sum()
# Out:
# 1258020056

# %%
data_Warner_Bros[data_Warner_Bros['release_year'] == 2010].profit.sum()
# Out:
# 1974712985

# %%
data_Warner_Bros[data_Warner_Bros['release_year'] == 2015].profit.sum()
# Out:
# 870368348

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
import pandas as pd
data = pd.read_csv('data.csv')
def change(t):
    tmp = str(t)
    t = t[:-7]
    if '/' in t:
        return int(t[:-1])
    else:
        return int(t)
data.release_date = data.release_date.apply(change)
data
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# 5     tt1663202    9.110700  135000000   532950503
# 6     tt1340138    8.654359  155000000   440603537
# 7     tt3659388    7.667400  108000000   595380321
# 8     tt2293640    7.404165   74000000  1156730962
# 9     tt2096673    6.326804  175000000   853708609
# 10    tt2379713    6.200282  245000000   880674609
# 11    tt1617661    6.189369  176000003   183987723
# 12    tt0470752    6.118847   15000000    36869414
# 13    tt2120120    5.984995   88000000   243637091
# 14    tt2395427    5.944927  280000000  1405035767
# 15    tt3460252    5.898400   44000000   155760117
# 16    tt2446042    5.749758   48000000   325771424
# ...

# %%
data[data.release_date == 2]
data[data.release_date == 6]
data[data.release_date == 12]
data[data.release_date == 9]
data[data.release_date == 5]
# Out:
#         imdb_id  popularity     budget    revenue  \
# 1     tt1392190   28.419936  150000000  378436354
# 20    tt1964418    5.462138  190000000  209035668
# 22    tt2126355    4.907832  110000000  470490832
# 31    tt2848292    3.877764   29000000  287506194
# 56    tt3079380    2.404473   65000000  235666219
# 73    tt1029360    1.984529   35000000   95437994
# 100   tt2967224    1.178831   35000000   51680201
# 111   tt1243974    0.814206   37000000   26250020
# 132   tt1877832    6.052479  250000000  746000000
# 143   tt1631867    3.990452  178000000  370541256
# 147   tt0831387    3.689601  160000000  529076069
# 148   tt1587310    3.582315  180000000  758410378
# 166   tt2883512    2.672350   11000000   45967935
# 173   tt1086772    2.445165   40000000  123494610
# 174   tt2004420    2.376309   18000000  268157400
# 177   tt2582846    2.293859   12000000  305151265
# 207   tt1100089    1.136851   24000000   12096300
# 209   tt2345737    1.052381   12250000    2295423
# ...

# %%
data[data.release_date == 2].count()
# Out:
# imdb_id                 135
# popularity              135
# budget                  135
# revenue                 135
# original_title          135
# cast                    135
# director                135
# tagline                 135
# overview                135
# runtime                 135
# genres                  135
# production_companies    135
# release_date            135
# vote_count              135
# vote_average            135
# release_year            135
# dtype: int64

# %%
data[data.release_date == 6].count()
# Out:
# imdb_id                 147
# popularity              147
# budget                  147
# revenue                 147
# original_title          147
# cast                    147
# director                147
# tagline                 147
# overview                147
# runtime                 147
# genres                  147
# production_companies    147
# release_date            147
# vote_count              147
# vote_average            147
# release_year            147
# dtype: int64

# %%
data[data.release_date == 12].count()
# Out:
# imdb_id                 191
# popularity              191
# budget                  191
# revenue                 191
# original_title          191
# cast                    191
# director                191
# tagline                 191
# overview                191
# runtime                 191
# genres                  191
# production_companies    191
# release_date            191
# vote_count              191
# vote_average            191
# release_year            191
# dtype: int64

# %%
data[data.release_date == 9].count()
# Out:
# imdb_id                 227
# popularity              227
# budget                  227
# revenue                 227
# original_title          227
# cast                    227
# director                227
# tagline                 227
# overview                227
# runtime                 227
# genres                  227
# production_companies    227
# release_date            227
# vote_count              227
# vote_average            227
# release_year            227
# dtype: int64

# %%
data[data.release_date == 5].count()
# Out:
# imdb_id                 140
# popularity              140
# budget                  140
# revenue                 140
# original_title          140
# cast                    140
# director                140
# tagline                 140
# overview                140
# runtime                 140
# genres                  140
# production_companies    140
# release_date            140
# vote_count              140
# vote_average            140
# release_year            140
# dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
data[(data.release_date == 6) | (data.release_date == 7) | (data.release_date == 8)].count()
# Out:
# imdb_id                 450
# popularity              450
# budget                  450
# revenue                 450
# original_title          450
# cast                    450
# director                450
# tagline                 450
# overview                450
# runtime                 450
# genres                  450
# production_companies    450
# release_date            450
# vote_count              450
# vote_average            450
# release_year            450
# dtype: int64

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
dir_all5 = data.query('director in ["Steven Soderbergh", "Christopher Nolan", "Clint Eastwood", "Ridley Scott", "Peter Jackson"]')
dir_all5_winter = dir_all5[(dir_all5.release_date == 12) | (dir_all5.release_date == 1) | (dir_all5.release_date == 2)]

# %%
dir_all5_winter[dir_all5_winter.director == 'Steven Soderbergh'].count()
# Out:
# imdb_id                 6
# popularity              6
# budget                  6
# revenue                 6
# original_title          6
# cast                    6
# director                6
# tagline                 6
# overview                6
# runtime                 6
# genres                  6
# production_companies    6
# release_date            6
# vote_count              6
# vote_average            6
# release_year            6
# dtype: int64

# %%
dir_all5_winter[dir_all5_winter.director == 'Christopher Nolan'].count()
# Out:
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# tagline                 0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# dtype: int64

# %%
dir_all5_winter[dir_all5_winter.director == 'Clint Eastwood'].count()
# Out:
# imdb_id                 6
# popularity              6
# budget                  6
# revenue                 6
# original_title          6
# cast                    6
# director                6
# tagline                 6
# overview                6
# runtime                 6
# genres                  6
# production_companies    6
# release_date            6
# vote_count              6
# vote_average            6
# release_year            6
# dtype: int64

# %%
dir_all5_winter[dir_all5_winter.director == 'Ridley Scott'].count()
# Out:
# imdb_id                 3
# popularity              3
# budget                  3
# revenue                 3
# original_title          3
# cast                    3
# director                3
# tagline                 3
# overview                3
# runtime                 3
# genres                  3
# production_companies    3
# release_date            3
# vote_count              3
# vote_average            3
# release_year            3
# dtype: int64

# %%
dir_all5_winter[dir_all5_winter.director == 'Peter Jackson'].count()
# Out:
# imdb_id                 7
# popularity              7
# budget                  7
# revenue                 7
# original_title          7
# cast                    7
# director                7
# tagline                 7
# overview                7
# runtime                 7
# genres                  7
# production_companies    7
# release_date            7
# vote_count              7
# vote_average            7
# release_year            7
# dtype: int64

# %%
ss = data.query('director in ["Steven Soderbergh"]')
winter_ss = ss[(ss.release_date == 12) | (ss.release_date == 1) | (ss.release_date == 2)]
winter_ss.count()
# Out:
# imdb_id                 6
# popularity              6
# budget                  6
# revenue                 6
# original_title          6
# cast                    6
# director                6
# tagline                 6
# overview                6
# runtime                 6
# genres                  6
# production_companies    6
# release_date            6
# vote_count              6
# vote_average            6
# release_year            6
# dtype: int64

# %%
cn = data.query('director in ["Christopher Nolan"]')
winter_cn = cn[(cn.release_date == 12) | (cn.release_date == 1) | (cn.release_date == 2)]
winter_cn.count()
# Out:
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# tagline                 0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# dtype: int64

# %%
ce = data.query('director in ["Clint Eastwood"]')
winter_ce = ce[(ce.release_date == 12) | (ce.release_date == 1) | (ce.release_date == 2)]
winter_ce.count()
# Out:
# imdb_id                 6
# popularity              6
# budget                  6
# revenue                 6
# original_title          6
# cast                    6
# director                6
# tagline                 6
# overview                6
# runtime                 6
# genres                  6
# production_companies    6
# release_date            6
# vote_count              6
# vote_average            6
# release_year            6
# dtype: int64

# %%
rs = data.query('director in ["Ridley Scott"]')
winter_rs = rs[(rs.release_date == 12) | (rs.release_date == 1) | (rs.release_date == 2)]
winter_rs.count()
# Out:
# imdb_id                 3
# popularity              3
# budget                  3
# revenue                 3
# original_title          3
# cast                    3
# director                3
# tagline                 3
# overview                3
# runtime                 3
# genres                  3
# production_companies    3
# release_date            3
# vote_count              3
# vote_average            3
# release_year            3
# dtype: int64

# %%
pj = data.query('director in ["Peter Jackson"]')
winter_pj = pj[(pj.release_date == 12) | (pj.release_date == 1) | (pj.release_date == 2)]
winter_pj.count()
# Out:
# imdb_id                 7
# popularity              7
# budget                  7
# revenue                 7
# original_title          7
# cast                    7
# director                7
# tagline                 7
# overview                7
# runtime                 7
# genres                  7
# production_companies    7
# release_date            7
# vote_count              7
# vote_average            7
# release_year            7
# dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
s = data.groupby(['release_date','release_year'])
s1 = s.profit.max().sort_values(ascending=False).head(20)
s1
# Out:
# release_date  release_year
# 12            2009            2544505847
#               2015            1868178225
# 6             2015            1363528810
# 4             2015            1316249360
#               2012            1299557910
# 7             2011            1202817822
# 11            2013            1124219009
# 12            2003            1024888979
# 4             2013            1015439994
# 6             2011             928746996
# 10            2012             908561013
# 6             2013             894761885
#               2006             865659812
#               2010             863171911
# 11            2001             851475550
# 12            2002             847287400
# 7             2012             831041287
# 3             2010             825467110
# 7             2008             816921825
# 6             2007             788212738
# Name: profit, dtype: int64

# %%
s = data.groupby(['release_date','release_year'])['profit'].max().sort_values(ascending=False).head(20)
s
# Out:
# release_date  release_year
# 12            2009            2544505847
#               2015            1868178225
# 6             2015            1363528810
# 4             2015            1316249360
#               2012            1299557910
# 7             2011            1202817822
# 11            2013            1124219009
# 12            2003            1024888979
# 4             2013            1015439994
# 6             2011             928746996
# 10            2012             908561013
# 6             2013             894761885
#               2006             865659812
#               2010             863171911
# 11            2001             851475550
# 12            2002             847287400
# 7             2012             831041287
# 3             2010             825467110
# 7             2008             816921825
# 6             2007             788212738
# Name: profit, dtype: int64

# %%
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
#data['len_movie'] = len(data['original_title'])
#data
prod_comp = data.loc[data.production_companies.str.contains('Universal')]
prod_comp
#prod_comp['len_movie_Universal'] = len(prod_comp['original_title'])
#data[data.production_companies.str.contains('Universal')].len_movie.mean()
#prod_comp = data.groupby(['production_companies'])
#s1 = s.profit.sum().sort_values(ascending=False).head(20)
#prod_comp.first()
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 4     tt2820852    9.335014  190000000  1506249360
# 8     tt2293640    7.404165   74000000  1156730962
# 12    tt0470752    6.118847   15000000    36869414
# 26    tt2637276    4.564549   68000000   215863606
# 31    tt2848292    3.877764   29000000   287506194
# 38    tt1398426    3.202719   28000000   201634991
# 47    tt2719848    2.798017   55000000   203427584
# 53    tt2717822    2.550747   70000000    17752940
# 61    tt3152624    2.317670   35000000   140795793
# 86    tt3850590    1.448002   15000000    61548707
# 117   tt3614530    0.435582    5000000     2333684
# 133   tt2872732    5.947136   40000000   463360063
# 150   tt1204977    3.489314    5000000   102529779
# 157   tt0829150    3.028769   70000000   215529201
# 167   tt2975578    2.611251    9000000   108782847
# 174   tt2004420    2.376309   18000000   268157400
# ...

# %%
#answer_ls.append(1)
answer_ls.append('?')

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
#answer_ls.append(1)
answer_ls.append('?')

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
#answer_ls.append(1)
answer_ls.append('?')

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
data.groupby(['original_title'])['vote_average'].max().sort_values(ascending=False).head(20)
# Out:
# original_title
# The Dark Knight                                      8.1
# Inside Out                                           8.0
# Interstellar                                         8.0
# The Imitation Game                                   8.0
# Room                                                 8.0
# Gone Girl                                            7.9
# The Lord of the Rings: The Return of the King        7.9
# The Grand Budapest Hotel                             7.9
# Memento                                              7.9
# The Pianist                                          7.9
# The Wolf of Wall Street                              7.9
# Guardians of the Galaxy                              7.9
# 12 Years a Slave                                     7.9
# Inception                                            7.9
# The Theory of Everything                             7.8
# Eternal Sunshine of the Spotless Mind                7.8
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
jd = data[data.cast.str.contains('Johnny Depp')]
jd_hbc = jd[jd.cast.str.contains('Helena Bonham Carter')]
jd_hbc.count()
# Out:
# imdb_id                 6
# popularity              6
# budget                  6
# revenue                 6
# original_title          6
# cast                    6
# director                6
# tagline                 6
# overview                6
# runtime                 6
# genres                  6
# production_companies    6
# release_date            6
# vote_count              6
# vote_average            6
# release_year            6
# profit                  6
# dtype: int64

# %%
hj = data[data.cast.str.contains('Hugh Jackman')]
hj_im = hj[hj.cast.str.contains('Ian McKellen')]
hj_im.count()
# Out:
# imdb_id                 5
# popularity              5
# budget                  5
# revenue                 5
# original_title          5
# cast                    5
# director                5
# tagline                 5
# overview                5
# runtime                 5
# genres                  5
# production_companies    5
# release_date            5
# vote_count              5
# vote_average            5
# release_year            5
# profit                  5
# dtype: int64

# %%
vd = data[data.cast.str.contains('Vin Diesel')]
vd_pw = vd[vd.cast.str.contains('Paul Walker')]
vd_pw.count()
# Out:
# imdb_id                 5
# popularity              5
# budget                  5
# revenue                 5
# original_title          5
# cast                    5
# director                5
# tagline                 5
# overview                5
# runtime                 5
# genres                  5
# production_companies    5
# release_date            5
# vote_count              5
# vote_average            5
# release_year            5
# profit                  5
# dtype: int64

# %%
asandler = data[data.cast.str.contains('Adam Sandler')]
asandler_kj = asandler[asandler.cast.str.contains('Kevin James')]
asandler_kj.count()
# Out:
# imdb_id                 5
# popularity              5
# budget                  5
# revenue                 5
# original_title          5
# cast                    5
# director                5
# tagline                 5
# overview                5
# runtime                 5
# genres                  5
# production_companies    5
# release_date            5
# vote_count              5
# vote_average            5
# release_year            5
# profit                  5
# dtype: int64

# %%
dr = data[data.cast.str.contains('Daniel Radcliffe')]
dr_rg = dr[dr.cast.str.contains('Rupert Grint')]
dr_rg.count()
# Out:
# imdb_id                 8
# popularity              8
# budget                  8
# revenue                 8
# original_title          8
# cast                    8
# director                8
# tagline                 8
# overview                8
# runtime                 8
# genres                  8
# production_companies    8
# release_date            8
# vote_count              8
# vote_average            8
# release_year            8
# profit                  8
# dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
Quentin_Tarantino = data[data.director.str.contains('Quentin Tarantino')]
Quentin_Tarantino.count()
# Out:
# imdb_id                 7
# popularity              7
# budget                  7
# revenue                 7
# original_title          7
# cast                    7
# director                7
# tagline                 7
# overview                7
# runtime                 7
# genres                  7
# production_companies    7
# release_date            7
# vote_count              7
# vote_average            7
# release_year            7
# profit                  7
# dtype: int64

# %%
Quentin_Tarantino[Quentin_Tarantino.profit > 0].count()
# Out:
# imdb_id                 6
# popularity              6
# budget                  6
# revenue                 6
# original_title          6
# cast                    6
# director                6
# tagline                 6
# overview                6
# runtime                 6
# genres                  6
# production_companies    6
# release_date            6
# vote_count              6
# vote_average            6
# release_year            6
# profit                  6
# dtype: int64

# %%
Steven_Soderbergh = data[data.director.str.contains('Steven Soderbergh')]
Steven_Soderbergh.count()
# Out:
# imdb_id                 13
# popularity              13
# budget                  13
# revenue                 13
# original_title          13
# cast                    13
# director                13
# tagline                 13
# overview                13
# runtime                 13
# genres                  13
# production_companies    13
# release_date            13
# vote_count              13
# vote_average            13
# release_year            13
# profit                  13
# dtype: int64

# %%
Steven_Soderbergh[Steven_Soderbergh.profit > 0].count()
# Out:
# imdb_id                 10
# popularity              10
# budget                  10
# revenue                 10
# original_title          10
# cast                    10
# director                10
# tagline                 10
# overview                10
# runtime                 10
# genres                  10
# production_companies    10
# release_date            10
# vote_count              10
# vote_average            10
# release_year            10
# profit                  10
# dtype: int64

# %%
Robert_Rodriguez = data[data.director.str.contains('Robert Rodriguez')]
Robert_Rodriguez.count()
# Out:
# imdb_id                 11
# popularity              11
# budget                  11
# revenue                 11
# original_title          11
# cast                    11
# director                11
# tagline                 11
# overview                11
# runtime                 11
# genres                  11
# production_companies    11
# release_date            11
# vote_count              11
# vote_average            11
# release_year            11
# profit                  11
# dtype: int64

# %%
Robert_Rodriguez[Robert_Rodriguez.profit > 0].count()
# Out:
# imdb_id                 8
# popularity              8
# budget                  8
# revenue                 8
# original_title          8
# cast                    8
# director                8
# tagline                 8
# overview                8
# runtime                 8
# genres                  8
# production_companies    8
# release_date            8
# vote_count              8
# vote_average            8
# release_year            8
# profit                  8
# dtype: int64

# %%
Christopher_Nolan = data[data.director.str.contains('Christopher Nolan')]
Christopher_Nolan.count()
# Out:
# imdb_id                 8
# popularity              8
# budget                  8
# revenue                 8
# original_title          8
# cast                    8
# director                8
# tagline                 8
# overview                8
# runtime                 8
# genres                  8
# production_companies    8
# release_date            8
# vote_count              8
# vote_average            8
# release_year            8
# profit                  8
# dtype: int64

# %%
Christopher_Nolan[Christopher_Nolan.profit > 0].count()
# Out:
# imdb_id                 8
# popularity              8
# budget                  8
# revenue                 8
# original_title          8
# cast                    8
# director                8
# tagline                 8
# overview                8
# runtime                 8
# genres                  8
# production_companies    8
# release_date            8
# vote_count              8
# vote_average            8
# release_year            8
# profit                  8
# dtype: int64

# %%
Clint_Eastwood = data[data.director.str.contains('Clint Eastwood')]
Clint_Eastwood.count()
# Out:
# imdb_id                 12
# popularity              12
# budget                  12
# revenue                 12
# original_title          12
# cast                    12
# director                12
# tagline                 12
# overview                12
# runtime                 12
# genres                  12
# production_companies    12
# release_date            12
# vote_count              12
# vote_average            12
# release_year            12
# profit                  12
# dtype: int64

# %%
Clint_Eastwood[Clint_Eastwood.profit > 0].count()
# Out:
# imdb_id                 10
# popularity              10
# budget                  10
# revenue                 10
# original_title          10
# cast                    10
# director                10
# tagline                 10
# overview                10
# runtime                 10
# genres                  10
# production_companies    10
# release_date            10
# vote_count              10
# vote_average            10
# release_year            10
# profit                  10
# dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id Answer
# 0    1      4
# 1    2      2
# 2    3      3
# 3    4      2
# 4    5      1
# 5    6      5
# 6    7      2
# 7    8      1
# 8    9      4
# 9   10      5
# 10  11      3
# 11  12      1
# 12  13      3
# 13  14      4
# 14  15      5
# 15  16      1
# 16  17      3
# 17  18      3
# 18  19      2
# 19  20      1
# 20  21      4
# 21  22      2
# 22  23      3
# 23  24      1
# 24  25      5
# 25  26      1
# 26  27      4
# 27  28      2
# 28  29      5
# 29  30      2
# 30  31      ?
# 31  32      ?
# 32  33      ?
# 33  34      1
# 34  35      5
# 35  36      4
